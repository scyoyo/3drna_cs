# %% [markdown]
# # Kaggle Submission: Stanford RNA 3D Folding Part 2
#
# 1. Install deps & load weights from Kaggle Datasets
# 2. Read test_sequences.csv + MSA
# 3. Run model(s) + diversity select top-5
# 4. Write submission.csv

# %%
import sys
from pathlib import Path
import pandas as pd

# Kaggle paths
INPUT = Path("/kaggle/input")
COMP = INPUT / "stanford-rna-3d-folding-2"
OUTPUT = Path("/kaggle/working")

# Add repo (upload as notebook companion or clone)
# sys.path.insert(0, str(OUTPUT / "3drna_cs"))

# %%
# test_sequences.csv
test_df = pd.read_csv(COMP / "test_sequences.csv")
print(test_df.shape)
print(test_df.columns.tolist())

# %%
# Run prediction pipeline
# from src.predict import run_pipeline
# run_pipeline(
#     test_csv=COMP / "test_sequences.csv",
#     submission_csv=OUTPUT / "submission.csv",
#     model_path=COMP / "model_3d.pt",  # attach dataset with weights
#     msa_dir=COMP / "MSA",
#     device="cuda",
#     use_rhofold=False,
# )

# %%
# Placeholder: build minimal submission from sample
sample = pd.read_csv(COMP / "sample_submission.csv")
sample.to_csv(OUTPUT / "submission.csv", index=False)
print("Saved submission.csv")
